# %% [markdown]
# LengthMethod:__len__()
# •The__len__()methodallowscustomobjectstodefinewhattheirlengthmeans.
# •Python'sbuilt-incollectionssuchaslists,tuples,dictionaries,andstringsallimplement
# thismethod.

# %%
#Example:
def__init__(self,songs):
returnlen(self.songs)
self.songs=songs
p=Playlist(["Song1","Song2","Song3"])
classPlaylist:
def__len__(self):
print(len(p))
